# %% [markdown]
# # ML Reference Materials

# %% [markdown]
# ## Section 2 - Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
data = pd.read_csv('./data/cost_revenue_clean.csv')
data
# Out:
#        budget_usd     world_usd  domestic_usd
# 0       1000000.0  2.600000e+01           0.0
# 1         10000.0  4.010000e+02         401.0
# 2        400000.0  4.230000e+02         423.0
# 3        750000.0  4.500000e+02           0.0
# 4         10000.0  5.270000e+02         527.0
# ...           ...           ...           ...
# 5029  225000000.0  1.519480e+09   623279547.0
# 5030  215000000.0  1.671641e+09   652198010.0
# 5031  306000000.0  2.058662e+09   936662225.0
# 5032  200000000.0  2.207616e+09   658672302.0
# 5033  425000000.0  2.783919e+09   760507625.0
#
# [5034 rows x 3 columns]

# %%
data.describe()
# Out:
#          budget_usd     world_usd  domestic_usd
# count  5.034000e+03  5.034000e+03  5.034000e+03
# mean   3.290784e+07  9.515685e+07  4.415985e+07
# std    4.112589e+07  1.726012e+08  6.737926e+07
# min    1.100000e+03  2.600000e+01  0.000000e+00
# 25%    6.000000e+06  7.000000e+06  3.209372e+06
# 50%    1.900000e+07  3.296202e+07  2.034680e+07
# 75%    4.200000e+07  1.034471e+08  5.600026e+07
# max    4.250000e+08  2.783919e+09  9.366622e+08

# %%
x = pd.DataFrame(data, columns=['budget_usd'])
y = pd.DataFrame(data, columns=['world_usd'])

# %%
# plot the data
plt.style.use('dark_background')
plt.figure(figsize=(10,6))
plt.scatter(x, y, alpha=0.3)
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.grid(color='w', alpha=0.2)
plt.title("Movie cost and Global revenue")
plt.xlabel("Production budget USD")
plt.ylabel("Gross revenues USD");

# %%
reg = LinearRegression()
reg.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# slope coefficient
reg.coef_
# Out:
# array([[3.11150918]])

# %%
# intercept
reg.intercept_
# Out:
# array([-7236192.72913963])

# %%
# New plot of the data and the regression line. 
plt.style.use('dark_background')
plt.figure(figsize=(10,6))
plt.scatter(x, y, alpha=0.3)
plt.plot(x, reg.predict(x), color='#e449f2', linewidth=2, alpha=0.5)
plt.grid(color='w', alpha=0.2)
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)
plt.title("Movie cost and Global revenue")
plt.xlabel("Production budget USD")
plt.ylabel("Gross revenues USD");

# %%
reg.score(x, y)
# Out:
# 0.5496485356985727
